# 34  <a href="http://twitter.com/download/iphone" r...
# 35  <a href="http://twitter.com/download/iphone" r...
# 36  <a href="http://twitter.com/download/iphone" r...
# 37  <a href="http://twitter.com/download/iphone" r...
# 38  <a href="http://twitter.com/download/iphone" r...
# 39  <a href="http://twitter.com/download/iphone" r...
# 40  <a href="http://twitter.com/download/iphone" r...
# 41  <a href="http://twitter.com/download/iphone" r...
# 42  <a href="http://twitter.com/download/iphone" r...
# 43  <a href="http://twitter.com/download/iphone" r...
# 44  <a href="http://twitter.com/download/iphone" r...
# 45  <a href="http://twitter.com/download/iphone" r...
# 46  <a href="http://twitter.com/download/iphone" r...
# 47  <a href="http://twitter.com/download/iphone" r...
# 48  <a href="http://twitter.com/download/iphone" r...
# 49  <a href="http://twitter.com/download/iphone" r...
#
#                                                  text  retweeted_status_id  \
# 0   This is Phineas. He's a mystical boy. Only eve...                  NaN
# 1   This is Tilly. She's just checking pup on you....                  NaN
# 2   This is Archie. He is a rare Norwegian Pouncin...                  NaN
# 3   This is Darla. She commenced a snooze mid meal...                  NaN
# 4   This is Franklin. He would like you to stop ca...                  NaN
# 5   Here we have a majestic great white breaching ...                  NaN
# 6   Meet Jax. He enjoys ice cream so much he gets ...                  NaN
# 7   When you watch your owner call another dog a g...                  NaN
# 8   This is Zoey. She doesn't want to be one of th...                  NaN
# 9   This is Cassie. She is a college pup. Studying...                  NaN
# 10  This is Koda. He is a South Australian decksha...                  NaN
# 11  This is Bruno. He is a service shark. Only get...                  NaN
# 12  Here's a puppo that seems to be on the fence a...                  NaN
# 13  This is Ted. He does his best. Sometimes that'...                  NaN
# 14  This is Stuart. He's sporting his favorite fan...                  NaN
# 15  This is Oliver. You're witnessing one of his m...                  NaN
# 16  This is Jim. He found a fren. Taught him how t...                  NaN
# 17  This is Zeke. He has a new stick. Very proud o...                  NaN
# 18  This is Ralphus. He's powering up. Attempting ...                  NaN
# 19  RT @dog_rates: This is Canela. She attempted s...         8.874740e+17
# 20  This is Gerald. He was just told he didn't get...                  NaN
# 21  This is Jeffrey. He has a monopoly on the pool...                  NaN
# 22  I've yet to rate a Venezuelan Hover Wiener. Th...                  NaN
# 23  This is Canela. She attempted some fancy porch...                  NaN
# 24  You may not have known you needed to see this ...                  NaN
# 25  This... is a Jubilant Antarctic House Bear. We...                  NaN
# 26  This is Maya. She's very shy. Rarely leaves he...                  NaN
# 27  This is Mingus. He's a wonderful father to his...                  NaN
# 28  This is Derek. He's late for a dog meeting. 13...                  NaN
# 29  This is Roscoe. Another pupper fallen victim t...                  NaN
# 30  @NonWhiteHat @MayhewMayhem omg hello tanner yo...                  NaN
# 31  This is Waffles. His doggles are pupside down....                  NaN
# 32  RT @Athletics: 12/10 #BATP https://t.co/WxwJmv...         8.860537e+17
# 33  Viewer discretion advised. This is Jimbo. He w...                  NaN
# 34  This is Maisey. She fell asleep mid-excavation...                  NaN
# 35  I have a new hero and his name is Howard. 14/1...                  NaN
# 36  RT @dog_rates: This is Lilly. She just paralle...         8.305833e+17
# 37  Here we have a corgi undercover as a malamute....                  NaN
# 38  This is Earl. He found a hat. Nervous about wh...                  NaN
# 39  This is Lola. It's her first time outside. Mus...                  NaN
# 40  This is Kevin. He's just so happy. 13/10 what ...                  NaN
# 41  I present to you, Pup in Hat. Pup in Hat is gr...                  NaN
# 42  OMG HE DIDN'T MEAN TO HE WAS JUST TRYING A LIT...                  NaN
# 43  Meet Yogi. He doesn't have any important dog m...                  NaN
= "https://d17h27t6h515a5.cloudfront.net/topher/2017/August/599fd2ad_image-predictions/image-predictions.tsv"
        response = requests.get(url)
        file.write(response.content)
    
Image_predictions_df = pd.read_csv('Data\\image-predictions.tsv',sep="\t")
Image_predictions_df.head()
# Out:
#              tweet_id                                          jpg_url  \
# 0  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2  666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3  666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4  666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
#
#    img_num                      p1   p1_conf  p1_dog                  p2  \
# 0        1  Welsh_springer_spaniel  0.465074    True              collie
# 1        1                 redbone  0.506826    True  miniature_pinscher
# 2        1         German_shepherd  0.596461    True            malinois
# 3        1     Rhodesian_ridgeback  0.408143    True             redbone
# 4        1      miniature_pinscher  0.560311    True          Rottweiler
#
#     p2_conf  p2_dog                   p3   p3_conf  p3_dog
# 0  0.156665    True    Shetland_sheepdog  0.061428    True
# 1  0.074192    True  Rhodesian_ridgeback  0.072010    True
# 2  0.138584    True           bloodhound  0.116197    True
# 3  0.360687    True   miniature_pinscher  0.222752    True
# 4  0.243682    True             Doberman  0.154629    True

# %%
if not os.path.exists('Data//tweet-json.txt'):
    os.rename('Data//tweet-json copy','Data//tweet-json.txt') 

f = open('Data//tweet-json.txt',"r") 
# json.loads(f.read())
data = [json.loads(line) for line in f]
#json.loads(f.read())
data
column_names =["id","retweet_count","favorite_count"]
dictionary={
            column_names[0]:[i["id"] for i in data],
            column_names[1]:[i["retweet_count"] for i in data],
            column_names[2]:[i["favorite_count"] for i in data],
           }
api_df = pd.DataFrame(dictionary)
api_df.head()
# Out:
#                    id  retweet_count  favorite_count
# 0  892420643555336193           8853           39467
# 1  892177421306343426           6514           33819
# 2  891815181378084864           4328           25461
# 3  891689557279858688           8964           42908
# 4  891327558926688256           9774           41048

# %%
archive_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   tweet_id                    2356 non-null   int64
#  1   in_reply_to_status_id       78 non-null     float64
#  2   in_reply_to_user_id         78 non-null     float64
#  3   timestamp                   2356 non-null   object
#  4   source                      2356 non-null   object
#  5   text                        2356 non-null   object
#  6   retweeted_status_id         181 non-null    float64
#  7   retweeted_status_user_id    181 non-null    float64
#  8   retweeted_status_timestamp  181 non-null    object
#  9   expanded_urls               2297 non-null   object
#  10  rating_numerator            2356 non-null   int64
#  11  rating_denominator          2356 non-null   int64
#  12  name                        2356 non-null   object
#  13  doggo                       2356 non-null   object
#  14  floofer                     2356 non-null   object
#  15  pupper                      2356 non-null   object
#  16  puppo                       2356 non-null   object
# dtypes: float64(4), int64(3), object(10)
# memory usage: 313.0+ KB

# %%
archive_df.describe()
# Out:
#            tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# count  2.356000e+03           7.800000e+01         7.800000e+01
# mean   7.427716e+17           7.455079e+17         2.014171e+16
# std    6.856705e+16           7.582492e+16         1.252797e+17
# min    6.660209e+17           6.658147e+17         1.185634e+07
# 25%    6.783989e+17           6.757419e+17         3.086374e+08
# 50%    7.196279e+17           7.038708e+17         4.196984e+09
# 75%    7.993373e+17           8.257804e+17         4.196984e+09
# max    8.924206e+17           8.862664e+17         8.405479e+17
#
#        retweeted_status_id  retweeted_status_user_id  rating_numerator  \
# count         1.810000e+02              1.810000e+02       2356.000000
# mean          7.720400e+17              1.241698e+16         13.126486
# std           6.236928e+16              9.599254e+16         45.876648
# min           6.661041e+17              7.832140e+05          0.000000
# 25%           7.186315e+17              4.196984e+09         10.000000
# 50%           7.804657e+17              4.196984e+09         11.000000
# 75%           8.203146e+17              4.196984e+09         12.000000
# max           8.874740e+17              7.874618e+17       1776.000000
#
#        rating_denominator
# count         2356.000000
# mean            10.455433
# std              6.745237
# min              0.000000
# 25%             10.000000
# 50%             10.000000
# 75%             10.000000
# max            170.000000

# %%
for i in archive_df.columns:
    print(f"{i} => \n{archive_df[i].value_counts()} \n\n")
# Out:
# tweet_id =>
# 749075273010798592    1
# 741099773336379392    1
# 798644042770751489    1
# 825120256414846976    1
# 769212283578875904    1
#                      ..
# 715360349751484417    1
# 666817836334096384    1
# 794926597468000259    1
# 673705679337693185    1
# 700151421916807169    1
# Name: tweet_id, Length: 2356, dtype: int64
#
#
# in_reply_to_status_id =>
# 6.671522e+17    2
# 8.562860e+17    1
# 8.131273e+17    1
# 6.754971e+17    1
# 6.827884e+17    1
#                ..
# 8.482121e+17    1
# 6.715449e+17    1
# 6.936422e+17    1
# 6.849598e+17    1
# 7.331095e+17    1
# Name: in_reply_to_status_id, Length: 77, dtype: int64
#
#
# in_reply_to_user_id =>
# 4.196984e+09    47
# 2.195506e+07     2
# 7.305050e+17     1
# 2.916630e+07     1
# 3.105441e+09     1
# 2.918590e+08     1
# 2.792810e+08     1
# 2.319108e+09     1
# 1.806710e+08     1
# 3.058208e+07     1
# 2.625958e+07     1
# 1.943518e+08     1
# 3.589728e+08     1
# 8.405479e+17     1
# 2.894131e+09     1
# 2.143566e+07     1
# 2.281182e+09     1
# 1.648776e+07     1
# 4.717297e+09     1
# 2.878549e+07     1
# 1.582854e+09     1
# 4.670367e+08     1
# 4.738443e+07     1
# 1.361572e+07     1
# 1.584641e+07     1
# 2.068372e+07     1
# 1.637468e+07     1
# 1.185634e+07     1
# 1.198989e+09     1
# 1.132119e+08     1
# 7.759620e+07     1
# Name: in_reply_to_user_id, dtype: int64
#
#
# timestamp =>
# 2015-12-12 15:59:51 +0000    1
# 2016-08-01 16:43:19 +0000    1
# 2016-02-15 01:05:02 +0000    1
# 2016-03-17 23:33:12 +0000    1
# 2016-09-21 00:53:04 +0000    1
#                             ..
# 2015-11-21 01:59:37 +0000    1
# 2017-06-10 16:39:04 +0000    1
# 2015-12-08 20:53:11 +0000    1
# 2016-06-27 16:08:30 +0000    1
# 2017-01-15 04:56:16 +0000    1
# Name: timestamp, Length: 2356, dtype: int64
#
#
# source =>
# <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>     2221
# <a href="http://vine.co" rel="nofollow">Vine - Make a Scene</a>                          91
# <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>                       33
# <a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>      11
# Name: source, dtype: int64
#
#
# text =>
# This is Miguel. He was the only remaining doggo at the adoption center after the weekend. Let's change that. 12/10\n\nhttps://t.co/P0bO8mCQwN https://t.co/SU4K34NT4M    1
# This is Tuco. That's the toast that killed his father. 9/10 https://t.co/ujnWy26RMe                                                                                      1
# #BarkWeek is getting rather heckin terrifying over here. Doin me quite the spooken. 13/10 (vid by @corgi_zero) https://t.co/eA7k1ZQslA                                   1
# This is Koda. She's a Beneboom Cumberwiggle. 12/10 petable as hell https://t.co/VZV6oMJmU6                                                                               1
# Meet Kayla, an underground poker legend. Players lose on purpose hoping she'll let them pet her. 10/10 strategic af https://t.co/EkLku795aO                              1
#                                                                                                                                                                         ..
# This is Timmy. He's quite large. According to a trusted source it's actually a dog wearing a dog suit. 11/10 https://t.co/BIUchFwHqn                                     1
# Here's a doggo blowing bubbles. It's downright legendary. 13/10 would watch on repeat forever (vid by Kent Duryee) https://t.co/YcXgHfp1EC                               1
# This is Doug. He's a Draconian Jabbawockee. Rad tongue. Ears are borderline legendary 11/10 would pet with a purpose https://t.co/MVvbQW88Pv                             1
# Please stop sending in saber-toothed tigers. This is getting ridiculous. We only rate dogs.\n...8/10 https://t.co/iAeQNueou8                                             1
# This dog is never sure if he's doing the right thing. 10/10 https://t.co/GXq43zFfBu                                                                                      1
# Name: text, Length: 2356, dtype: int64
#
#
# retweeted_status_id =>
# 7.757333e+17    1
# 7.507196e+17    1
# 6.742918e+17    1
# 6.833919e+17    1
# 8.269587e+17    1
#                ..
# 7.848260e+17    1
# 7.806013e+17    1
# 8.305833e+17    1
# 7.047611e+17    1
# 7.331095e+17    1
# Name: retweeted_status_id, Length: 181, dtype: int64
#
#
# retweeted_status_user_id =>
# 4.196984e+09    156
# 4.296832e+09      2
# 5.870972e+07      1
# 6.669901e+07      1
# 4.119842e+07      1
# 7.475543e+17      1
# 7.832140e+05      1
# 7.266347e+08      1
# 4.871977e+08      1
# 5.970642e+08      1
# 4.466750e+07      1
# 1.228326e+09      1
# 7.992370e+07      1
# 2.488557e+07      1
# 7.874618e+17      1
# 3.638908e+08      1
# 5.128045e+08      1
# 8.117408e+08      1
# 1.732729e+09      1
# 1.960740e+07      1
# 1.547674e+08      1
# 3.410211e+08      1
# 7.124572e+17      1
# 2.804798e+08      1
# 1.950368e+08      1
# Name: retweeted_status_user_id, dtype: int64
#
#
# retweeted_status_timestamp =>
# 2016-08-15 16:22:20 +0000    1
# 2016-06-08 22:48:46 +0000    1
# 2016-09-28 00:46:20 +0000    1
# 2016-05-19 01:38:16 +0000    1
# 2016-09-01 16:14:48 +0000    1
#                             ..
# 2016-07-30 17:56:51 +0000    1
# 2017-01-11 02:15:36 +0000    1
# 2017-05-22 00:28:40 +0000    1
# 2016-10-06 01:23:05 +0000    1
# 2017-02-18 01:39:12 +0000    1
# Name: retweeted_status_timestamp, Length: 181, dtype: int64
#
#
# expanded_urls =>
# https://www.gofundme.com/3hgsuu0,https://twitter.com/dog_rates/status/840632337062862849/photo/1                                   2
# https://twitter.com/dog_rates/status/680055455951884288/photo/1                                                                    2
# https://twitter.com/dog_rates/status/687317306314240000/photo/1,https://twitter.com/dog_rates/status/687317306314240000/photo/1    2
# https://twitter.com/dog_rates/status/669000397445533696/photo/1                                                                    2
# https://twitter.com/dog_rates/status/753375668877008896/photo/1                                                                    2
#                                                                                                                                   ..
# https://twitter.com/dog_rates/status/668641109086707712/photo/1                                                                    1
# https://twitter.com/dog_rates/status/702217446468493312/photo/1                                                                    1
# https://twitter.com/dog_rates/status/670428280563085312/photo/1                                                                    1
# https://twitter.com/dog_rates/status/708119489313951744/photo/1                                                                    1
# https://twitter.com/dog_rates/status/704819833553219584/photo/1                                                                    1
# Name: expanded_urls, Length: 2218, dtype: int64
#
#
# rating_numerator =>
# 12      558
# 11      464
# 10      461
# 13      351
# 9       158
# 8       102
# 7        55
# 14       54
# 5        37
# 6        32
# 3        19
# 4        17
# 1         9
# 2         9
# 420       2
# 0         2
# 15        2
# 75        2
# 80        1
# 20        1
# 24        1
# 26        1
# 44        1
# 50        1
# 60        1
# 165       1
# 84        1
# 88        1
# 144       1
# 182       1
# 143       1
# 666       1
# 960       1
# 1776      1
# 17        1
# 27        1
# 45        1
# 99        1
# 121       1
# 204       1
# Name: rating_numerator, dtype: int64
#
#
# rating_denominator =>
# 10     2333
# 11        3
# 50        3
# 80        2
# 20        2
# 2         1
# 16        1
# 40        1
# 70        1
# 15        1
# 90        1
# 110       1
# 120       1
# 130       1
# 150       1
# 170       1
# 7         1
# 0         1
# Name: rating_denominator, dtype: int64
#
#
# name =>
# None       745
# a           55
# Charlie     12
# Cooper      11
# Lucy        11
#           ...
# Cheesy       1
# Sobe         1
# Brian        1
# by           1
# Trip         1
# Name: name, Length: 957, dtype: int64
#
#
# doggo =>
# None     2259
# doggo      97
# Name: doggo, dtype: int64
#
#
# floofer =>
# None       2346
# floofer      10
# Name: floofer, dtype: int64
#
#
# pupper =>
# None      2099
# pupper     257
# Name: pupper, dtype: int64
#
#
# puppo =>
# None     2326
# puppo      30
# Name: puppo, dtype: int64

# %%
sum(archive_df.duplicated())
# Out:
# 0

# %%
Image_predictions_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   tweet_id  2075 non-null   int64
#  1   jpg_url   2075 non-null   object
#  2   img_num   2075 non-null   int64
#  3   p1        2075 non-null   object
#  4   p1_conf   2075 non-null   float64
#  5   p1_dog    2075 non-null   bool
#  6   p2        2075 non-null   object
#  7   p2_conf   2075 non-null   float64
#  8   p2_dog    2075 non-null   bool
#  9   p3        2075 non-null   object
#  10  p3_conf   2075 non-null   float64
#  11  p3_dog    2075 non-null   bool
# dtypes: bool(3), float64(3), int64(2), object(4)
# memory usage: 152.1+ KB

# %%
api_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2354 entries, 0 to 2353
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              2354 non-null   int64
#  1   retweet_count   2354 non-null   int64
#  2   favorite_count  2354 non-null   int64
# dtypes: int64(3)
# memory usage: 55.3 KB

# %%
archive_df_cleaned = archive_df.copy()
Image_predictions_df_cleaned = Image_predictions_df.copy()
api_df_cleaned = api_df.copy()

# %%
retweets_ids = list(archive_df_cleaned[archive_df_cleaned.retweeted_status_id.notnull() | archive_df_cleaned.in_reply_to_status_id.notnull()].tweet_id)
# Drop Retweetsfrom archive_df_cleaned
archive_df_cleaned = archive_df_cleaned[~archive_df_cleaned.tweet_id.isin(retweets_ids)]
archive_df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2097 entries, 0 to 2355
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   tweet_id                    2097 non-null   int64
#  1   in_reply_to_status_id       0 non-null      float64
#  2   in_reply_to_user_id         0 non-null      float64
#  3   timestamp                   2097 non-null   object
#  4   source                      2097 non-null   object
#  5   text                        2097 non-null   object
#  6   retweeted_status_id         0 non-null      float64
#  7   retweeted_status_user_id    0 non-null      float64
#  8   retweeted_status_timestamp  0 non-null      object
#  9   expanded_urls               2094 non-null   object
#  10  rating_numerator            2097 non-null   int64
#  11  rating_denominator          2097 non-null   int64
#  12  name                        2097 non-null   object
#  13  doggo                       2097 non-null   object
#  14  floofer                     2097 non-null   object
#  15  pupper                      2097 non-null   object
#  16  puppo                       2097 non-null   object
# dtypes: float64(4), int64(3), object(10)
# memory usage: 294.9+ KB

# %%
archive_df_cleaned.drop(['in_reply_to_status_id','in_reply_to_user_id','retweeted_status_id','retweeted_status_user_id','retweeted_status_timestamp'],axis=1,inplace = True)
archive_df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2097 entries, 0 to 2355
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tweet_id            2097 non-null   int64
#  1   timestamp           2097 non-null   object
#  2   source              2097 non-null   object
#  3   text                2097 non-null   object
#  4   expanded_urls       2094 non-null   object
#  5   rating_numerator    2097 non-null   int64
#  6   rating_denominator  2097 non-null   int64
#  7   name                2097 non-null   object
#  8   doggo               2097 non-null   object
#  9   floofer             2097 non-null   object
#  10  pupper              2097 non-null   object
#  11  puppo               2097 non-null   object
# dtypes: int64(3), object(9)
# memory usage: 213.0+ KB

# %%
archive_df_cleaned = archive_df_cleaned[archive_df['expanded_urls'].notnull()]
archive_df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2094 entries, 0 to 2355
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tweet_id            2094 non-null   int64
#  1   timestamp           2094 non-null   object
#  2   source              2094 non-null   object
#  3   text                2094 non-null   object
#  4   expanded_urls       2094 non-null   object
#  5   rating_numerator    2094 non-null   int64
#  6   rating_denominator  2094 non-null   int64
#  7   name                2094 non-null   object
#  8   doggo               2094 non-null   object
#  9   floofer             2094 non-null   object
#  10  pupper              2094 non-null   object
#  11  puppo               2094 non-null   object
# dtypes: int64(3), object(9)
# memory usage: 212.7+ KB
# <ipython-input-446-7442cd007fea>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   archive_df_cleaned = archive_df_cleaned[archive_df['expanded_urls'].notnull()]

# %%
archive_df_cleaned['timestamp'] = pd.to_datetime(archive_df_cleaned['timestamp'])
archive_df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2094 entries, 0 to 2355
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tweet_id            2094 non-null   int64
#  1   timestamp           2094 non-null   datetime64[ns, UTC]
#  2   source              2094 non-null   object
#  3   text                2094 non-null   object
#  4   expanded_urls       2094 non-null   object
#  5   rating_numerator    2094 non-null   int64
#  6   rating_denominator  2094 non-null   int64
#  7   name                2094 non-null   object
#  8   doggo               2094 non-null   object
#  9   floofer             2094 non-null   object
#  10  pupper              2094 non-null   object
#  11  puppo               2094 non-null   object
# dtypes: datetime64[ns, UTC](1), int64(3), object(8)
# memory usage: 212.7+ KB

# %%
archive_df_cleaned['tweet_id'] = archive_df_cleaned['tweet_id'].astype(str)
archive_df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2094 entries, 0 to 2355
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tweet_id            2094 non-null   object
#  1   timestamp           2094 non-null   datetime64[ns, UTC]
#  2   source              2094 non-null   object
#  3   text                2094 non-null   object
#  4   expanded_urls       2094 non-null   object
#  5   rating_numerator    2094 non-null   int64
#  6   rating_denominator  2094 non-null   int64
#  7   name                2094 non-null   object
#  8   doggo               2094 non-null   object
#  9   floofer             2094 non-null   object
#  10  pupper              2094 non-null   object
#  11  puppo               2094 non-null   object
# dtypes: datetime64[ns, UTC](1), int64(2), object(9)
# memory usage: 212.7+ KB

# %%
sum(archive_df_cleaned.duplicated())
# Out:
# 0

# %%
archive_df_cleaned.name.value_counts()
archive_df_cleaned[archive_df_cleaned.name=="a"].text.index
# Out:
# Int64Index([  56,  649,  801, 1002, 1004, 1017, 1049, 1193, 1207, 1340, 1351,
#             1361, 1368, 1382, 1499, 1737, 1785, 1853, 1854, 1877, 1878, 1923,
#             1941, 1955, 1994, 2034, 2066, 2116, 2125, 2128, 2146, 2153, 2161,
#             2191, 2198, 2211, 2218, 2222, 2235, 2249, 2255, 2264, 2273, 2287,
#             2304, 2311, 2314, 2327, 2334, 2347, 2348, 2350, 2352, 2353, 2354],
#            dtype='int64')

# %%
regex = r"This is \w\w\w+|His name is \w+|Meet \w+|Say hello to \w+|named \w+"

#looping over data frame raws which contain name value "a" and try to extract the right name from column text 
for text ,index in zip(archive_df_cleaned[archive_df_cleaned.name=="a"].text,archive_df_cleaned[archive_df_cleaned.name=="a"].index) :
    try:
        name = re.findall(regex,text)[0].split()[-1]
        #assignig the found name to the row of data frame 
        archive_df_cleaned.at[index, 'name'] = name
    except IndexError as e:
        pass
    
archive_df_cleaned.name.value_counts()
# Out:
# None       600
# a           35
# Charlie     11
# Lucy        11
# Cooper      10
#           ...
# Chevy        1
# Happy        1
# Kaia         1
# Tripp        1
# Trip         1
# Name: name, Length: 972, dtype: int64

# %%
archive_df_cleaned['name'] = archive_df_cleaned['name'].str.capitalize()
archive_df_cleaned.name.value_counts()
# Out:
# None          600
# A              35
# Lucy           11
# Charlie        11
# Cooper         10
#              ...
# Jarvis          1
# Chevy           1
# Happy           1
# Officially      1
# Trip            1
# Name: name, Length: 972, dtype: int64

# %%
regex = r"(\d+\.?\d*\/\d+)"
rating = []
#looping over data frame raws which contain name value "a" and try to extract the right name from column text 
for text ,index in zip(archive_df_cleaned.text,archive_df_cleaned.index) :
    try:
        name = re.search(regex,text).group()
        rating.append(name)
    except IndexError as e:
        pass
    
archive_df_cleaned['rating'] = rating
archive_df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2094 entries, 0 to 2355
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tweet_id            2094 non-null   object
#  1   timestamp           2094 non-null   datetime64[ns, UTC]
#  2   source              2094 non-null   object
#  3   text                2094 non-null   object
#  4   expanded_urls       2094 non-null   object
#  5   rating_numerator    2094 non-null   int64
#  6   rating_denominator  2094 non-null   int64
#  7   name                2094 non-null   object
#  8   doggo               2094 non-null   object
#  9   floofer             2094 non-null   object
#  10  pupper              2094 non-null   object
#  11  puppo               2094 non-null   object
#  12  rating              2094 non-null   object
# dtypes: datetime64[ns, UTC](1), int64(2), object(10)
# memory usage: 309.0+ KB

# %%
archive_df_cleaned.drop(['rating_denominator','rating_numerator'],axis=1,inplace=True)
archive_df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2094 entries, 0 to 2355
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   tweet_id       2094 non-null   object
#  1   timestamp      2094 non-null   datetime64[ns, UTC]
#  2   source         2094 non-null   object
#  3   text           2094 non-null   object
#  4   expanded_urls  2094 non-null   object
#  5   name           2094 non-null   object
#  6   doggo          2094 non-null   object
#  7   floofer        2094 non-null   object
#  8   pupper         2094 non-null   object
#  9   puppo          2094 non-null   object
#  10  rating         2094 non-null   object
# dtypes: datetime64[ns, UTC](1), object(10)
# memory usage: 276.3+ KB

# %%
archive_df_cleaned.doggo = archive_df_cleaned.doggo.replace("None","")
archive_df_cleaned.floofer = archive_df_cleaned.floofer.replace("None","")
archive_df_cleaned.pupper = archive_df_cleaned.pupper.replace("None","")
archive_df_cleaned.puppo = archive_df_cleaned.puppo.replace("None","")
# concat all columns to new column dog_stage 
archive_df_cleaned["dog_stage"]= archive_df_cleaned["doggo"] +archive_df_cleaned["floofer"]+archive_df_cleaned["pupper"]+archive_df_cleaned["puppo"]

#displaying dog_stage to find concatenated stages 
archive_df_cleaned.dog_stage.value_counts()
# Out:
#                 1759
# pupper           220
# doggo             72
# puppo             23
# floofer            9
# doggopupper        9
# doggopuppo         1
# doggofloofer       1
# Name: dog_stage, dtype: int64

# %%
# add hyphen to any concatenated 
archive_df_cleaned.dog_stage=archive_df_cleaned.dog_stage.replace("doggopupper","doggo-pupper")
archive_df_cleaned.dog_stage=archive_df_cleaned.dog_stage.replace("doggofloofer","doggo-floofer")
archive_df_cleaned.dog_stage=archive_df_cleaned.dog_stage.replace("doggopuppo","doggo-puppo")
archive_df_cleaned.dog_stage.value_counts()
# Out:
#                  1759
# pupper            220
# doggo              72
# puppo              23
# floofer             9
# doggo-pupper        9
# doggo-floofer       1
# doggo-puppo         1
# Name: dog_stage, dtype: int64

# %%
archive_df_cleaned.dog_stage = archive_df_cleaned.dog_stage.replace("",np.nan)
archive_df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2094 entries, 0 to 2355
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   tweet_id       2094 non-null   object
#  1   timestamp      2094 non-null   datetime64[ns, UTC]
#  2   source         2094 non-null   object
#  3   text           2094 non-null   object
#  4   expanded_urls  2094 non-null   object
#  5   name           2094 non-null   object
#  6   doggo          2094 non-null   object
#  7   floofer        2094 non-null   object
#  8   pupper         2094 non-null   object
#  9   puppo          2094 non-null   object
#  10  rating         2094 non-null   object
#  11  dog_stage      335 non-null    object
# dtypes: datetime64[ns, UTC](1), object(11)
# memory usage: 292.7+ KB

# %%
# Out:
# '13.5/10'

# %%
archive_df_cleaned.drop(["doggo" ,"floofer" ,"pupper","puppo"],axis=1 ,inplace=True)

archive_df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2094 entries, 0 to 2355
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   tweet_id       2094 non-null   object
#  1   timestamp      2094 non-null   datetime64[ns, UTC]
#  2   source         2094 non-null   object
#  3   text           2094 non-null   object
#  4   expanded_urls  2094 non-null   object
#  5   name           2094 non-null   object
#  6   rating         2094 non-null   object
#  7   dog_stage      335 non-null    object
# dtypes: datetime64[ns, UTC](1), object(7)
# memory usage: 227.2+ KB

# %%
archive_df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2297 entries, 0 to 2355
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   tweet_id       2297 non-null   object
#  1   timestamp      2297 non-null   datetime64[ns, UTC]
#  2   source         2297 non-null   object
#  3   text           2297 non-null   object
#  4   expanded_urls  2297 non-null   object
#  5   name           2297 non-null   object
#  6   rating         2297 non-null   object
#  7   dog_stage      374 non-null    object
# dtypes: datetime64[ns, UTC](1), object(7)
# memory usage: 241.5+ KB

# %%
Image_predictions_df_cleaned.tweet_id = Image_predictions_df_cleaned.tweet_id.astype(str)
Image_predictions_df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   tweet_id  2075 non-null   object
#  1   jpg_url   2075 non-null   object
#  2   img_num   2075 non-null   int64
#  3   p1        2075 non-null   object
#  4   p1_conf   2075 non-null   float64
#  5   p1_dog    2075 non-null   bool
#  6   p2        2075 non-null   object
#  7   p2_conf   2075 non-null   float64
#  8   p2_dog    2075 non-null   bool
#  9   p3        2075 non-null   object
#  10  p3_conf   2075 non-null   float64
#  11  p3_dog    2075 non-null   bool
# dtypes: bool(3), float64(3), int64(1), object(5)
# memory usage: 152.1+ KB

# %%
api_df_cleaned = api_df_cleaned.rename(columns = {'id': 'tweet_id'})

# %%
api_df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2354 entries, 0 to 2353
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tweet_id        2354 non-null   int64
#  1   retweet_count   2354 non-null   int64
#  2   favorite_count  2354 non-null   int64
# dtypes: int64(3)
# memory usage: 55.3 KB

# %%
Image_predictions_df_cleaned = Image_predictions_df_cleaned.rename(columns = {'p1' : 'prediction_1','p2' : 'prediction_2',
                                                                             'p3' : 'prediction_3','p1_dog' : 'prediction_1_is_dog','p2_dog' : 'prediction_2_is_dog',
                                                                             'p3_dog' : 'prediction_3_is_dog','p1_conf' : 'prediction_1_confidence',
                                                                             'p2_conf' : 'prediction_2_confidence','p3_conf' : 'prediction_3_confidence'})
Image_predictions_df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   tweet_id                 2075 non-null   object
#  1   jpg_url                  2075 non-null   object
#  2   img_num                  2075 non-null   int64
#  3   prediction_1             2075 non-null   object
#  4   prediction_1_confidence  2075 non-null   float64
#  5   prediction_1_is_dog      2075 non-null   bool
#  6   prediction_2             2075 non-null   object
#  7   prediction_2_confidence  2075 non-null   float64
#  8   prediction_2_is_dog      2075 non-null   bool
#  9   prediction_3             2075 non-null   object
#  10  prediction_3_confidence  2075 non-null   float64
#  11  prediction_3_is_dog      2075 non-null   bool
# dtypes: bool(3), float64(3), int64(1), object(5)
# memory usage: 152.1+ KB

# %%
api_df_cleaned['tweet_id'] = api_df_cleaned['tweet_id'].astype(str)

# %%
#cheking for names and its count 
for name,count in zip(archive_df_cleaned.name.value_counts().sort_values(ascending=False).index.tolist(),archive_df_cleaned.name.value_counts(ascending=False).sort_values(ascending=False)):
    print("count is :{}\tname is :{}".format(count,name))
# Out:
# count is :600	name is :None
# count is :35	name is :A
# count is :11	name is :Lucy
# count is :11	name is :Charlie
# count is :10	name is :Cooper
# count is :10	name is :Oliver
# count is :9	name is :Tucker
# count is :9	name is :Penny
# count is :8	name is :Winston
# count is :8	name is :Sadie
# count is :8	name is :The
# count is :8	name is :Lola
# count is :7	name is :Daisy
# count is :7	name is :Toby
# count is :6	name is :Jax
# count is :6	name is :Oscar
# count is :6	name is :Bailey
# count is :6	name is :Bella
# count is :6	name is :Stanley
# count is :6	name is :An
# count is :6	name is :Koda
# count is :6	name is :Bo
# count is :5	name is :Scout
# count is :5	name is :Bentley
# count is :5	name is :Milo
# count is :5	name is :Louis
# count is :5	name is :Chester
# count is :5	name is :Buddy
# count is :5	name is :Dave
# count is :5	name is :Leo
# count is :5	name is :Rusty
# count is :4	name is :Boomer
# count is :4	name is :Reggie
# count is :4	name is :Clarence
# count is :4	name is :Clark
# count is :4	name is :Larry
# count is :4	name is :Phil
# count is :4	name is :George
# count is :4	name is :Bear
# count is :4	name is :Jerry
# count is :4	name is :Jeffrey
# count is :4	name is :Dexter
# count is :4	name is :Jack
# count is :4	name is :Very
# count is :4	name is :Cassie
# count is :4	name is :Duke
# count is :4	name is :Brody
# count is :4	name is :Winnie
# count is :4	name is :Oakley
# count is :4	name is :Sophie
# count is :4	name is :Derek
# count is :4	name is :Scooter
# count is :4	name is :One
# count is :4	name is :Archie
# count is :4	name is :Alfie
# count is :4	name is :Finn
# count is :4	name is :Gus
# count is :4	name is :Maggie
# count is :4	name is :Gary
# count is :4	name is :Chip
# count is :4	name is :Sammy
# count is :3	name is :Sunny
# count is :3	name is :Wallace
# count is :3	name is :Loki
# count is :3	name is :Vincent
# count is :3	name is :Ted
# count is :3	name is :Calvin
# count is :3	name is :Zeke
# count is :3	name is :Olive
# count is :3	name is :Mia
# count is :3	name is :Otis
# count is :3	name is :Doug
# count is :3	name is :Reese
# count is :3	name is :Malcolm
# count is :2	name is :Cupcake
# count is :2	name is :Doc
# count is :2	name is :Franklin
# count is :2	name is :Aspen
# count is :2	name is :Misty
# count is :2	name is :Titan
# count is :2	name is :Paisley
# count is :2	name is :Sam
# count is :2	name is :Jiminy
# count is :2	name is :Finley
# count is :2	name is :Rocco
# count is :2	name is :Charles
# count is :2	name is :Kreggory
# count is :2	name is :Roosevelt
# count is :2	name is :Atticus
# count is :2	name is :Bubbles
# count is :2	name is :Getting
# count is :2	name is :Peaches
# count is :2	name is :Arnie
# count is :2	name is :Oliviér
# count is :2	name is :Axel
# count is :2	name is :Smokey
# count is :2	name is :Pickles
# count is :2	name is :Olivia
# count is :2	name is :Atlas
# count is :2	name is :Coops
# count is :2	name is :Chipson
# count is :2	name is :Lenny
# count is :2	name is :Jessiga
# count is :2	name is :Dakota
# count is :2	name is :Percy
# count is :2	name is :Hunter
# count is :2	name is :Jackson
# count is :2	name is :Kilo
# count is :2	name is :Elliot
# count is :2	name is :Ash
# count is :2	name is :Raymond
# count is :2	name is :Tyr
# count is :2	name is :Phred
# count is :2	name is :Harold
# count is :2	name is :Marley
# count is :2	name is :Mister
# count is :2	name is :Herm
# count is :2	name is :Linda
# count is :2	name is :Maxaroni
# count is :2	name is :Yogi
# count is :2	name is :Hobbes
# count is :2	name is :Cash
# count is :2	name is :Rocky
# count is :2	name is :Fiona
# count is :2	name is :Benji
# count is :2	name is :Lennon
# count is :2	name is :Panda
# count is :2	name is :Watson
# count is :2	name is :Eli
# count is :2	name is :Albus
# count is :2	name is :Lorenzo
# count is :2	name is :Phineas
# count is :1	name is :Kuyu
# count is :1	name is :Smiley
# count is :1	name is :Jonah
# count is :1	name is :Bungalo
# count is :1	name is :Superpup
# count is :1	name is :Bode
# count is :1	name is :Perry
# count is :1	name is :Clarkus
# count is :1	name is :Tito
# count is :1	name is :Kevon
# count is :1	name is :Baron
# count is :1	name is :Farfle
# count is :1	name is :Jockson
# count is :1	name is :Kota
# count is :1	name is :Autumn
# count is :1	name is :Sora
# count is :1	name is :Grizzwald
# count is :1	name is :Ronnie
# count is :1	name is :Emmy
# count is :1	name is :Shelby
# count is :1	name is :Strudel
# count is :1	name is :Blue
# count is :1	name is :Carper
# count is :1	name is :Mairi
# count is :1	name is :Samsom
# count is :1	name is :Canela
# count is :1	name is :Tycho
# count is :1	name is :Ricky
# count is :1	name is :Oreo
# count is :1	name is :Such
# count is :1	name is :Mingus
# count is :1	name is :Tommy
# count is :1	name is :Flurpson
# count is :1	name is :Shooter
# count is :1	name is :Ashleigh
# count is :1	name is :Jaycob
# count is :1	name is :Alexander
# count is :1	name is :Fabio
# count is :1	name is :Durg
# count is :1	name is :Kial
# count is :1	name is :Bobby
# count is :1	name is :Christoper
# count is :1	name is :Kona
# count is :1	name is :Malikai
# count is :1	name is :Lilli
# count is :1	name is :Bauer
# count is :1	name is :Tater
# count is :1	name is :Kendall
# count is :1	name is :Vixen
# count is :1	name is :Balto
# count is :1	name is :Darrel
# count is :1	name is :Corey
# count is :1	name is :Angel
# count is :1	name is :Snoopy
# count is :1	name is :Ed
# count is :1	name is :Incredibly
# count is :1	name is :Devón
# count is :1	name is :Jackie
# count is :1	name is :Marlee
# count is :1	name is :Levi
# count is :1	name is :Rover
# count is :1	name is :Beckham
# count is :1	name is :Kawhi
# count is :1	name is :Chesney
# count is :1	name is :Kanu
# count is :1	name is :Bobble
# count is :1	name is :Stephan
# count is :1	name is :Karma
# count is :1	name is :Jo
# count is :1	name is :Theo
# count is :1	name is :Traviss
# count is :1	name is :Charl
# count is :1	name is :Pipsy
# count is :1	name is :Arya
# count is :1	name is :Shadoe
# count is :1	name is :Kobe
# count is :1	name is :Hector
# count is :1	name is :Wafer
# count is :1	name is :Rhino
# count is :1	name is :Sailer
# count is :1	name is :Bobb
# count is :1	name is :Clifford
# count is :1	name is :Emanuel
# count is :1	name is :Peanut
# count is :1	name is :Clyde
# count is :1	name is :Buddah
# count is :1	name is :Alf
# count is :1	name is :Jim
# count is :1	name is :Bruno
# count is :1	name is :Hercules
# count is :1	name is :Carbon
# count is :1	name is :Goliath
# count is :1	name is :Reagan
# count is :1	name is :Arlen
# count is :1	name is :Dudley
# count is :1	name is :Colin
# count is :1	name is :Moreton
# count is :1	name is :Bonaparte
# count is :1	name is :Spark
# count is :1	name is :Lulu
# count is :1	name is :Seamus
# count is :1	name is :Mitch
# count is :1	name is :Stubert
# count is :1	name is :Ike
# count is :1	name is :Glenn
# count is :1	name is :Stefan
# count is :1	name is :Callie
# count is :1	name is :Meera
# count is :1	name is :Kyro
# count is :1	name is :Odin
# count is :1	name is :Lili
# count is :1	name is :Crumpet
# count is :1	name is :Ulysses
# count is :1	name is :Glacier
# count is :1	name is :Chubbs
# count is :1	name is :Rilo
# count is :1	name is :Gustaf
# count is :1	name is :Simba
# count is :1	name is :Jeb
# count is :1	name is :Ginger
# count is :1	name is :Snoop
# count is :1	name is :Mad
# count is :1	name is :Rufio
# count is :1	name is :Pawnd
# count is :1	name is :Amber
# count is :1	name is :Fwed
# count is :1	name is :Snickers
# count is :1	name is :Iggy
# count is :1	name is :Ronduh
# count is :1	name is :Tebow
# count is :1	name is :Iroh
# count is :1	name is :Aldrick
# count is :1	name is :Tove
# count is :1	name is :Donny
# count is :1	name is :Sailor
# count is :1	name is :Brutus
# count is :1	name is :Ridley
# count is :1	name is :Blanket
# count is :1	name is :Ito
# count is :1	name is :Chef
# count is :1	name is :Godzilla
# count is :1	name is :Anna
# count is :1	name is :Chadrick
# count is :1	name is :Taz
# count is :1	name is :Molly
# count is :1	name is :Kollin
# count is :1	name is :Josep
# count is :1	name is :Socks
# count is :1	name is :Ambrose
# count is :1	name is :Ralphson
# count is :1	name is :Katie
# count is :1	name is :Jacob
# count is :1	name is :Cali
# count is :1	name is :Nugget
# count is :1	name is :Billl
# count is :1	name is :Officially
# count is :1	name is :Hurley
# count is :1	name is :Mya
# count is :1	name is :Ivar
# count is :1	name is :Sully
# count is :1	name is :Obi
# count is :1	name is :Carly
# count is :1	name is :Yoda
# count is :1	name is :Rey
# count is :1	name is :Skye
# count is :1	name is :Pablo
# count is :1	name is :Bookstore
# count is :1	name is :Bell
# count is :1	name is :Jarod
# count is :1	name is :Enchilada
# count is :1	name is :Mason
# count is :1	name is :Grey
# count is :1	name is :Ember
# count is :1	name is :Rumpole
# count is :1	name is :River
# count is :1	name is :Antony
# count is :1	name is :Caryl
# count is :1	name is :Hall
# count is :1	name is :Unacceptable
# count is :1	name is :Tess
# count is :1	name is :Dook
# count is :1	name is :Rooney
# count is :1	name is :Chompsky
# count is :1	name is :Mutt
# count is :1	name is :Jebberson
# count is :1	name is :Kramer
# count is :1	name is :Chuck
# count is :1	name is :Remus
# count is :1	name is :O
# count is :1	name is :Jomathan
# count is :1	name is :Clybe
# count is :1	name is :Shaggy
# count is :1	name is :Taco
# count is :1	name is :Holly
# count is :1	name is :Edgar
# count is :1	name is :Coleman
# count is :1	name is :By
# count is :1	name is :Mike
# count is :1	name is :Huxley
# count is :1	name is :Lilly
# count is :1	name is :Tedders
# count is :1	name is :Oddie
# count is :1	name is :Buckley
# count is :1	name is :Tonks
# count is :1	name is :Hanz
# count is :1	name is :Lizzie
# count is :1	name is :Leonidas
# count is :1	name is :Lassie
# count is :1	name is :Asher
# count is :1	name is :Crawford
# count is :1	name is :Lucia
# count is :1	name is :Meyer
# count is :1	name is :Spanky
# count is :1	name is :Staniel
# count is :1	name is :Harnold
# count is :1	name is :Cora
# count is :1	name is :Stephanus
# count is :1	name is :Miguel
# count is :1	name is :Mojo
# count is :1	name is :Yukon
# count is :1	name is :Fiji
# count is :1	name is :Lugan
# count is :1	name is :Timber
# count is :1	name is :Gromit
# count is :1	name is :Jareld
# count is :1	name is :Danny
# count is :1	name is :Willem
# count is :1	name is :Pinot
# count is :1	name is :Ralf
# count is :1	name is :Betty
# count is :1	name is :Dido
# count is :1	name is :Storkson
# count is :1	name is :Jerome
# count is :1	name is :Bloop
# count is :1	name is :Rodman
# count is :1	name is :Bert
# count is :1	name is :Blu
# count is :1	name is :Fizz
# count is :1	name is :Obie
# count is :1	name is :Severus
# count is :1	name is :Willie
# count is :1	name is :Einstein
# count is :1	name is :Lance
# count is :1	name is :Trip
# count is :1	name is :Schnitzel
# count is :1	name is :Ole
# count is :1	name is :Harrison
# count is :1	name is :Timofy
# count is :1	name is :Pumpkin
# count is :1	name is :Dot
# count is :1	name is :Kloey
# count is :1	name is :Julio
# count is :1	name is :Mabel
# count is :1	name is :Grady
# count is :1	name is :Todo
# count is :1	name is :Sprinkles
# count is :1	name is :Dayz
# count is :1	name is :Marq
# count is :1	name is :His
# count is :1	name is :Champ
# count is :1	name is :Halo
# count is :1	name is :Light
# count is :1	name is :Dixie
# count is :1	name is :Brandy
# count is :1	name is :Brandi
# count is :1	name is :Tango
# count is :1	name is :Arnold
# count is :1	name is :Mollie
# count is :1	name is :Klein
# count is :1	name is :Lupe
# count is :1	name is :Stuart
# count is :1	name is :Bobbay
# count is :1	name is :Thor
# count is :1	name is :Sweets
# count is :1	name is :Ralphy
# count is :1	name is :Huck
# count is :1	name is :Genevieve
# count is :1	name is :Brockly
# count is :1	name is :Fynn
# count is :1	name is :Rueben
# count is :1	name is :Boston
# count is :1	name is :My
# count is :1	name is :Cilantro
# count is :1	name is :Bodie
# count is :1	name is :Vince
# count is :1	name is :Bayley
# count is :1	name is :Rolf
# count is :1	name is :Linus
# count is :1	name is :Georgie
# count is :1	name is :Brandonald
# count is :1	name is :Gin
# count is :1	name is :Alfonso
# count is :1	name is :Fillup
# count is :1	name is :Sunshine
# count is :1	name is :Evy
# count is :1	name is :Carll
# count is :1	name is :Freddery
# count is :1	name is :Meatball
# count is :1	name is :Nida
# count is :1	name is :Shnuggles
# count is :1	name is :Pepe
# count is :1	name is :Maya
# count is :1	name is :Dug
# count is :1	name is :Dale
# count is :1	name is :Berb
# count is :1	name is :Karl
# count is :1	name is :Michelangelope
# count is :1	name is :Kathmandu
# count is :1	name is :Striker
# count is :1	name is :Zoe
# count is :1	name is :Anthony
# count is :1	name is :Richie
# count is :1	name is :Dallas
# count is :1	name is :Eriq
# count is :1	name is :Ace
# count is :1	name is :Bruiser
# count is :1	name is :Wiggles
# count is :1	name is :Sprout
# count is :1	name is :Sonny
# count is :1	name is :Swagger
# count is :1	name is :Schnozz
# count is :1	name is :Brat
# count is :1	name is :Scruffers
# count is :1	name is :Siba
# count is :1	name is :Quinn
# count is :1	name is :Rontu
# count is :1	name is :Finnegus
# count is :1	name is :Hazel
# count is :1	name is :Saydee
# count is :1	name is :Dondon
# count is :1	name is :Andru
# count is :1	name is :Lacy
# count is :1	name is :Jamesy
# count is :1	name is :Robin
# count is :1	name is :Ralph
# count is :1	name is :Infuriating
# count is :1	name is :Tuco
# count is :1	name is :Monster
# count is :1	name is :Cherokee
# count is :1	name is :Laela
# count is :1	name is :Anakin
# count is :1	name is :Raphael
# count is :1	name is :Marty
# count is :1	name is :Dawn
# count is :1	name is :Alfredo
# count is :1	name is :Aubie
# count is :1	name is :Link
# count is :1	name is :Old
# count is :1	name is :Kody
# count is :1	name is :Daniel
# count is :1	name is :Diogi
# count is :1	name is :Crouton
# count is :1	name is :Kirk
# count is :1	name is :Sid
# count is :1	name is :Kulet
# count is :1	name is :Pilot
# count is :1	name is :Johm
# count is :1	name is :Timison
# count is :1	name is :Major
# count is :1	name is :Jessifer
# count is :1	name is :Rupert
# count is :1	name is :Lucky
# count is :1	name is :Shawwn
# count is :1	name is :Leela
# count is :1	name is :Acro
# count is :1	name is :Claude
# count is :1	name is :Jeffrie
# count is :1	name is :Ralphus
# count is :1	name is :Norman
# count is :1	name is :Eazy
# count is :1	name is :Steve
# count is :1	name is :Rubio
# count is :1	name is :Spencer
# count is :1	name is :Banditt
# count is :1	name is :Geoff
# count is :1	name is :Alphred
# count is :1	name is :Millie
# count is :1	name is :Andy
# count is :1	name is :Brian
# count is :1	name is :Spork
# count is :1	name is :Sobe
# count is :1	name is :Bebe
# count is :1	name is :Cheesy
# count is :1	name is :Moofasa
# count is :1	name is :Maxwell
# count is :1	name is :Loomis
# count is :1	name is :Mo
# count is :1	name is :Eugene
# count is :1	name is :Dietrich
# count is :1	name is :Tobi
# count is :1	name is :Pavlov
# count is :1	name is :Harlso
# count is :1	name is :Venti
# count is :1	name is :Philbert
# count is :1	name is :Rascal
# count is :1	name is :Newt
# count is :1	name is :General
# count is :1	name is :Jameson
# count is :1	name is :Dutch
# count is :1	name is :Happy
# count is :1	name is :Chevy
# count is :1	name is :Jarvis
# count is :1	name is :Rudy
# count is :1	name is :Maude
# count is :1	name is :Trigger
# count is :1	name is :Winifred
# count is :1	name is :Biden
# count is :1	name is :Blakely
# count is :1	name is :Kaia
# count is :1	name is :Emma
# count is :1	name is :Dewey
# count is :1	name is :Marvin
# count is :1	name is :Vinnie
# count is :1	name is :Cuddles
# count is :1	name is :Gert
# count is :1	name is :Butters
# count is :1	name is :Monty
# count is :1	name is :Aiden
# count is :1	name is :Beebop
# count is :1	name is :Doobert
# count is :1	name is :Mimosa
# count is :1	name is :Tripp
# count is :1	name is :Travis
# count is :1	name is :Willow
# count is :1	name is :Laika
# count is :1	name is :Mary
# count is :1	name is :Mona
# count is :1	name is :Kallie
# count is :1	name is :Bones
# count is :1	name is :Cleopatricia
# count is :1	name is :Lolo
# count is :1	name is :Chelsea
# count is :1	name is :Poppy
# count is :1	name is :Gerbald
# count is :1	name is :Alfy
# count is :1	name is :Octaviath
# count is :1	name is :Rorie
# count is :1	name is :Lambeau
# count is :1	name is :Edmund
# count is :1	name is :Goose
# count is :1	name is :Jeremy
# count is :1	name is :Maks
# count is :1	name is :Kellogg
# count is :1	name is :Mark
# count is :1	name is :Sierra
# count is :1	name is :Pluto
# count is :1	name is :Comet
# count is :1	name is :Barclay
# count is :1	name is :Pepper
# count is :1	name is :Kip
# count is :1	name is :Ron
# count is :1	name is :Eevee
# count is :1	name is :Maisey
# count is :1	name is :Covach
# count is :1	name is :Bilbo
# count is :1	name is :Chuk
# count is :1	name is :Howie
# count is :1	name is :Hemry
# count is :1	name is :Gunner
# count is :1	name is :Aqua
# count is :1	name is :Bronte
# count is :1	name is :Ziva
# count is :1	name is :Patch
# count is :1	name is :Kenny
# count is :1	name is :Flash
# count is :1	name is :Cedrick
# count is :1	name is :Harry
# count is :1	name is :Clarq
# count is :1	name is :Al
# count is :1	name is :Longfellow
# count is :1	name is :Timmy
# count is :1	name is :Rodney
# count is :1	name is :Strider
# count is :1	name is :Shiloh
# count is :1	name is :Chloe
# count is :1	name is :Napolean
# count is :1	name is :Henry
# count is :1	name is :Milky
# count is :1	name is :Billy
# count is :1	name is :Coopson
# count is :1	name is :Sundance
# count is :1	name is :Furzey
# count is :1	name is :Bradlay
# count is :1	name is :Chaz
# count is :1	name is :Grizz
# count is :1	name is :Cupid
# count is :1	name is :Emmie
# count is :1	name is :Arlo
# count is :1	name is :Torque
# count is :1	name is :Creg
# count is :1	name is :Harvey
# count is :1	name is :Orion
# count is :1	name is :Bradley
# count is :1	name is :Eleanor
# count is :1	name is :Kohl
# count is :1	name is :Duchess
# count is :1	name is :Binky
# count is :1	name is :Franq
# count is :1	name is :Rizzo
# count is :1	name is :Suki
# count is :1	name is :Beemo
# count is :1	name is :Klint
# count is :1	name is :Horace
# count is :1	name is :Nico
# count is :1	name is :Charleson
# count is :1	name is :Crimson
# count is :1	name is :Zara
# count is :1	name is :Pippin
# count is :1	name is :Jazzy
# count is :1	name is :Craig
# count is :1	name is :Puff
# count is :1	name is :Daryl
# count is :1	name is :Murphy
# count is :1	name is :Tayzie
# count is :1	name is :Tedrick
# count is :1	name is :Stella
# count is :1	name is :Amélie
# count is :1	name is :Godi
# count is :1	name is :Jd
# count is :1	name is :Wesley
# count is :1	name is :Dotsy
# count is :1	name is :Grizzie
# count is :1	name is :Derby
# count is :1	name is :Dwight
# count is :1	name is :Ralphie
# count is :1	name is :Ralphé
# count is :1	name is :Willy
# count is :1	name is :Florence
# count is :1	name is :Stormy
# count is :1	name is :Stark
# count is :1	name is :Paull
# count is :1	name is :Herb
# count is :1	name is :Rizzy
# count is :1	name is :Heinrich
# count is :1	name is :Tyrone
# count is :1	name is :Tiger
# count is :1	name is :Opie
# count is :1	name is :Ruffles
# count is :1	name is :William
# count is :1	name is :Aja
# count is :1	name is :Apollo
# count is :1	name is :Jersey
# count is :1	name is :Ben
# count is :1	name is :Remy
# count is :1	name is :Gustav
# count is :1	name is :Mauve
# count is :1	name is :Akumi
# count is :1	name is :Rinna
# count is :1	name is :Izzy
# count is :1	name is :Berkeley
# count is :1	name is :Randall
# count is :1	name is :Zooey
# count is :1	name is :Noosh
# count is :1	name is :Logan
# count is :1	name is :Sojourner
# count is :1	name is :Boots
# count is :1	name is :Terrenth
# count is :1	name is :Jaspers
# count is :1	name is :Life
# count is :1	name is :Jed
# count is :1	name is :Nigel
# count is :1	name is :Birf
# count is :1	name is :Erik
# count is :1	name is :Noah
# count is :1	name is :Pancake
# count is :1	name is :Gordon
# count is :1	name is :Jiminus
# count is :1	name is :Wishes
# count is :1	name is :Tanner
# count is :1	name is :Mack
# count is :1	name is :Duddles
# count is :1	name is :Jangle
# count is :1	name is :Jeffri
# count is :1	name is :Koko
# count is :1	name is :Kaiya
# count is :1	name is :Stewie
# count is :1	name is :Hero
# count is :1	name is :Dante
# count is :1	name is :Rumble
# count is :1	name is :Cecil
# count is :1	name is :Liam
# count is :1	name is :Sky
# count is :1	name is :Sandra
# count is :1	name is :Lorelei
# count is :1	name is :Juckson
# count is :1	name is :Cannon
# count is :1	name is :Hamrick
# count is :1	name is :Dunkin
# count is :1	name is :Jazz
# count is :1	name is :Naphaniel
# count is :1	name is :Jennifur
# count is :1	name is :Butter
# count is :1	name is :Luther
# count is :1	name is :Ozzie
# count is :1	name is :Beya
# count is :1	name is :Tilly
# count is :1	name is :Pete
# count is :1	name is :Edd
# count is :1	name is :Banjo
# count is :1	name is :Vinscent
# count is :1	name is :Bloo
# count is :1	name is :Alejandro
# count is :1	name is :Benny
# count is :1	name is :Jett
# count is :1	name is :Fletcher
# count is :1	name is :Astrid
# count is :1	name is :Leroi
# count is :1	name is :Sephie
# count is :1	name is :Humphrey
# count is :1	name is :Zuzu
# count is :1	name is :Sparky
# count is :1	name is :Hubertson
# count is :1	name is :Harper
# count is :1	name is :Kenzie
# count is :1	name is :Darby
# count is :1	name is :Brady
# count is :1	name is :Kane
# count is :1	name is :Damon
# count is :1	name is :Rambo
# count is :1	name is :Jimbo
# count is :1	name is :Adele
# count is :1	name is :Lilah
# count is :1	name is :Julius
# count is :1	name is :Lenox
# count is :1	name is :Bowie
# count is :1	name is :Gilbert
# count is :1	name is :Jordy
# count is :1	name is :Geno
# count is :1	name is :Tyrus
# count is :1	name is :Skittles
# count is :1	name is :Margo
# count is :1	name is :Augie
# count is :1	name is :Scott
# count is :1	name is :Ferg
# count is :1	name is :Amy
# count is :1	name is :Joey
# count is :1	name is :Nollie
# count is :1	name is :Snicku
# count is :1	name is :Bertson
# count is :1	name is :Tassy
# count is :1	name is :Gòrdón
# count is :1	name is :Eve
# count is :1	name is :Shikha
# count is :1	name is :Divine
# count is :1	name is :Brownie
# count is :1	name is :Baloo
# count is :1	name is :Rose
# count is :1	name is :Mattie
# count is :1	name is :Cermet
# count is :1	name is :Roscoe
# count is :1	name is :Dobby
# count is :1	name is :Mookie
# count is :1	name is :Terrance
# count is :1	name is :Stu
# count is :1	name is :Pherb
# count is :1	name is :Lipton
# count is :1	name is :Chuq
# count is :1	name is :Pupcasso
# count is :1	name is :Reptar
# count is :1	name is :Space
# count is :1	name is :Tom
# count is :1	name is :Zeek
# count is :1	name is :Walker
# count is :1	name is :Burt
# count is :1	name is :Sage
# count is :1	name is :Chesterson
# count is :1	name is :Batdog
# count is :1	name is :Ken
# count is :1	name is :Miley
# count is :1	name is :Petrick
# count is :1	name is :Zeus
# count is :1	name is :Olaf
# count is :1	name is :Gidget
# count is :1	name is :Brudge
# count is :1	name is :Tuck
# count is :1	name is :Tug
# count is :1	name is :Monkey
# count is :1	name is :Brooks
# count is :1	name is :Ester
# count is :1	name is :Darla
# count is :1	name is :Leonard
# count is :1	name is :Deacon
# count is :1	name is :Kara
# count is :1	name is :Griswold
# count is :1	name is :Dylan
# count is :1	name is :Pip
# count is :1	name is :Ebby
# count is :1	name is :Sweet
# count is :1	name is :Nimbus
# count is :1	name is :Filup
# count is :1	name is :Jay
# count is :1	name is :Bubba
# count is :1	name is :Mosby
# count is :1	name is :Mac
# count is :1	name is :Tino
# count is :1	name is :Barney
# count is :1	name is :Herschel
# count is :1	name is :Kingsley
# count is :1	name is :Trevith
# count is :1	name is :Lillie
# count is :1	name is :Dex
# count is :1	name is :Keet
# count is :1	name is :Livvie
# count is :1	name is :Wylie
# count is :1	name is :Bluebert
# count is :1	name is :Karll
# count is :1	name is :Kayla
# count is :1	name is :All
# count is :1	name is :Combo
# count is :1	name is :Chase
# count is :1	name is :Shakespeare
# count is :1	name is :Toffee
# count is :1	name is :Davey
# count is :1	name is :Fido
# count is :1	name is :Philippe
# count is :1	name is :Hermione
# count is :1	name is :This
# count is :1	name is :Alexanderson
# count is :1	name is :Barry
# count is :1	name is :Blipson
# count is :1	name is :Joshwa
# count is :1	name is :Frönq
# count is :1	name is :Ralpher
# count is :1	name is :Tupawc
# count is :1	name is :Teddy
# count is :1	name is :Pubert
# count is :1	name is :Cal
# count is :1	name is :Carter
# count is :1	name is :Skittle

# %%
archive_df_cleaned_2 = archive_df_cleaned.copy()
Image_predictions_df_cleaned_2 = Image_predictions_df_cleaned.copy()
api_df_cleaned_2 = api_df_cleaned.copy()

# %%
tweets_data_df = archive_df_cleaned_2.merge(Image_predictions_df_cleaned2, how='inner', on='tweet_id')

# %%
tweets_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1971 entries, 0 to 1970
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   tweet_id                 1971 non-null   object
#  1   timestamp                1971 non-null   datetime64[ns, UTC]
#  2   source                   1971 non-null   object
#  3   text                     1971 non-null   object
#  4   expanded_urls            1971 non-null   object
#  5   name                     1971 non-null   object
#  6   rating                   1971 non-null   object
#  7   dog_stage                303 non-null    object
#  8   jpg_url                  1971 non-null   object
#  9   img_num                  1971 non-null   int64
#  10  prediction_1             1971 non-null   object
#  11  prediction_1_confidence  1971 non-null   float64
#  12  prediction_1_is_dog      1971 non-null   bool
#  13  prediction_2             1971 non-null   object
#  14  prediction_2_confidence  1971 non-null   float64
#  15  prediction_2_is_dog      1971 non-null   bool
#  16  prediction_3             1971 non-null   object
#  17  prediction_3_confidence  1971 non-null   float64
#  18  prediction_3_is_dog      1971 non-null   bool
# dtypes: bool(3), datetime64[ns, UTC](1), float64(3), int64(1), object(11)
# memory usage: 267.5+ KB

# %%
tweets_data_df_all = tweets_data_df.merge(api_df_cleaned_2, how='inner', on='tweet_id')

# %%
tweets_data_df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1971 entries, 0 to 1970
# Data columns (total 21 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   tweet_id                 1971 non-null   object
#  1   timestamp                1971 non-null   datetime64[ns, UTC]
#  2   source                   1971 non-null   object
#  3   text                     1971 non-null   object
#  4   expanded_urls            1971 non-null   object
#  5   name                     1971 non-null   object
#  6   rating                   1971 non-null   object
#  7   dog_stage                303 non-null    object
#  8   jpg_url                  1971 non-null   object
#  9   img_num                  1971 non-null   int64
#  10  prediction_1             1971 non-null   object
#  11  prediction_1_confidence  1971 non-null   float64
#  12  prediction_1_is_dog      1971 non-null   bool
#  13  prediction_2             1971 non-null   object
#  14  prediction_2_confidence  1971 non-null   float64
#  15  prediction_2_is_dog      1971 non-null   bool
#  16  prediction_3             1971 non-null   object
#  17  prediction_3_confidence  1971 non-null   float64
#  18  prediction_3_is_dog      1971 non-null   bool
#  19  retweet_count            1971 non-null   int64
#  20  favorite_count           1971 non-null   int64
# dtypes: bool(3), datetime64[ns, UTC](1), float64(3), int64(3), object(11)
# memory usage: 298.3+ KB

# %%
tweets_data_df_all.to_csv('Data//twitter_archive_master.csv',index=False)

# %%
twitter_archive_master = pd.read_csv('Data\\twitter_archive_master.csv')
twitter_archive_master.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1971 entries, 0 to 1970
# Data columns (total 21 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   tweet_id                 1971 non-null   int64
#  1   timestamp                1971 non-null   object
#  2   source                   1971 non-null   object
#  3   text                     1971 non-null   object
#  4   expanded_urls            1971 non-null   object
#  5   name                     1971 non-null   object
#  6   rating                   1971 non-null   object
#  7   dog_stage                303 non-null    object
#  8   jpg_url                  1971 non-null   object
#  9   img_num                  1971 non-null   int64
#  10  prediction_1             1971 non-null   object
#  11  prediction_1_confidence  1971 non-null   float64
#  12  prediction_1_is_dog      1971 non-null   bool
#  13  prediction_2             1971 non-null   object
#  14  prediction_2_confidence  1971 non-null   float64
#  15  prediction_2_is_dog      1971 non-null   bool
#  16  prediction_3             1971 non-null   object
#  17  prediction_3_confidence  1971 non-null   float64
#  18  prediction_3_is_dog      1971 non-null   bool
#  19  retweet_count            1971 non-null   int64
#  20  favorite_count           1971 non-null   int64
# dtypes: bool(3), float64(3), int64(4), object(11)
# memory usage: 283.1+ KB

# %%
tweet = twitter_archive_master[twitter_archive_master.favorite_count == twitter_archive_master.favorite_count.max()]
tweet.source
# Out:
# 306    <a href="http://twitter.com/download/iphone" r...
# Name: source, dtype: object

# %%
plt.bar(np.array(twitter_archive_master['timestamp']),
np.array(twitter_archive_master['retweet_count']))
plt.ylabel("retweet_countretweet_count") 
plt.xlabel("timestamp")  
plt.show()

# %%
plt.plot(np.array(twitter_archive_master['timestamp']),
np.array(twitter_archive_master['retweet_count']),linewidth=4)
plt.ylabel("retweet_countretweet_count") 
plt.xlabel("timestamp")  
plt.show()

# %%
tweets_data_df=tweets_data_df.set_index('timestamp')

# Use seaborn style defaults and set the default figure size to show retwwets count over time 
sns.set(rc={'figure.figsize':(11, 4)})
tweets_data_df['retweet_count'].plot(linewidth=0.5).set(xlabel="Year and month", ylabel = "count of retweets ")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-542-21ddebee8441> in <module>
# ----> 1 tweets_data_df=tweets_data_df.set_index('timestamp')
#       2
#       3 # Use seaborn style defaults and set the default figure size to show retwwets count over time
#       4 sns.set(rc={'figure.figsize':(11, 4)})
#       5 tweets_data_df['retweet_count'].plot(linewidth=0.5).set(xlabel="Year and month", ylabel = "count of retweets ")
#
# D:\anaconda3\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4549
#    4550         if missing:
# -> 4551             raise KeyError(f"None of {missing} are in the columns")
#    4552
#    4553         if inplace:
#
# KeyError: "None of ['timestamp'] are in the columns"

# %%
names=twitter_archive_master.name.value_counts(ascending=False).sort_values(ascending=False).index.tolist()[1:11]
counts=twitter_archive_master.name.value_counts(ascending=False).sort_values(ascending=False).tolist()[1:11]
plt.barh(names,
counts,color='#f00')
plt.ylabel("Dogs Names") 
plt.xlabel("Names counts")  
plt.show()

# %%
breeds=twitter_archive_master.prediction_value.value_counts(ascending=False).sort_values(ascending=False).index.tolist()[0:11]
counts=twitter_archive_master.prediction_value.value_counts(ascending=False).sort_values(ascending=False).tolist()[0:11]
plt.barh(breeds,
counts)
plt.ylabel("Dogs breeds") 
plt.xlabel("breeds counts")  
plt.show()
